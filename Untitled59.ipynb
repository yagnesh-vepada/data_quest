# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import metrics
data=pd.read_excel("Data Sheet.xlsx")

# %%
x=data.iloc[:,1:]
y=data.iloc[:,:1]

# %%
l=['Alcohol_Consumption','Crash_Type','Seatbelt_Usage','Road_Surface_Condition']
for i in l:
    print(i,data[i].unique())
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df=pd.DataFrame()
for i in l:
    df[i]=encoder.fit_transform(x[i])
x=x.drop(l,axis='columns')
x=pd.concat([x,df],axis='columns')
# Out:
# Alcohol_Consumption ['Yes' 'No']
# Crash_Type ['Rear-end' 'Head-on']
# Seatbelt_Usage ['No' 'Yes']
# Road_Surface_Condition ['Icy' 'Dry' 'Wet']

# %%
l2=['Gender','Vehicle_Type','Road_Type']
Gender=pd.get_dummies(x["Gender"],drop_first=True)
Vehicle_Type=pd.get_dummies(x["Vehicle_Type"],drop_first=True)
Road_Type=pd.get_dummies(x["Road_Type"],drop_first=True)

# %%
x=x.drop(l2,axis='columns')

# %%
x=pd.concat([x,Gender,Vehicle_Type,Road_Type],axis=1)

# %%
#kothaga doing

# %%
x
# Out:
#      Vehicle_Speed  Crash_Time  Age  Number_of_Lanes  Lane_Width  Speed_Limit  \
# 0              107          11   27                2    3.484386           30
# 1               27          16   39                2    3.293091          110
# 2               87          14   42                3    3.218911           59
# 3               43           3   60                2    3.113012           73
# 4               72           8   70                3    3.106580           42
# ..             ...         ...  ...              ...         ...          ...
# 295            112           4   30                1    3.248476          118
# 296             87          21   52                2    3.037739           38
# 297             85          20   79                2    3.350668           80
# 298             44           5   23                3    3.419304           47
# 299             68          12   30                1    3.357638          120
#
# ...

# %%
x.Vehicle_Speed=x.Vehicle_Speed/x.Speed_Limit

# %%
x.Age=x.Age/100

# %%
x
# Out:
#      Vehicle_Speed  Crash_Time   Age  Number_of_Lanes  Lane_Width  \
# 0         3.566667          11  0.27                2    3.484386
# 1         0.245455          16  0.39                2    3.293091
# 2         1.474576          14  0.42                3    3.218911
# 3         0.589041           3  0.60                2    3.113012
# 4         1.714286           8  0.70                3    3.106580
# ..             ...         ...   ...              ...         ...
# 295       0.949153           4  0.30                1    3.248476
# 296       2.289474          21  0.52                2    3.037739
# 297       1.062500          20  0.79                2    3.350668
# 298       0.936170           5  0.23                3    3.419304
# 299       0.566667          12  0.30                1    3.357638
#
#      Speed_Limit  Alcohol_Consumption  Crash_Type  Seatbelt_Usage  \
# 0             30                    1           1               0
# ...

# %%
x.Crash_Time=x.Crash_Time//30

# %%
col=["Speed_Limit"]
x=x.drop(col,axis='columns')

# %%
x
# Out:
#      Vehicle_Speed  Crash_Time   Age  Number_of_Lanes  Lane_Width  \
# 0         3.566667           0  0.27                2    3.484386
# 1         0.245455           0  0.39                2    3.293091
# 2         1.474576           0  0.42                3    3.218911
# 3         0.589041           0  0.60                2    3.113012
# 4         1.714286           0  0.70                3    3.106580
# ..             ...         ...   ...              ...         ...
# 295       0.949153           0  0.30                1    3.248476
# 296       2.289474           0  0.52                2    3.037739
# 297       1.062500           0  0.79                2    3.350668
# 298       0.936170           0  0.23                3    3.419304
# 299       0.566667           0  0.30                1    3.357638
#
#      Alcohol_Consumption  Crash_Type  Seatbelt_Usage  Road_Surface_Condition  \
# 0                      1           1               0                       1
# ...

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.svm import SVC
y=y.values.ravel()
folds=StratifiedKFold(n_splits=15)
from sklearn.model_selection import cross_val_score
scores=cross_val_score(model,x,y,cv=folds)
print(np.mean(scores))
# Out:
# 0.32

# %%
from sklearn.neighbors import KNeighborsClassifier
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train,y_train)
    print(knn.score(x_test,y_test))
# Out:
# 0.4
# 0.4
# 0.36666666666666664
# 0.4
# 0.36666666666666664
# 0.4
# 0.4166666666666667
# 0.35
# 0.4166666666666667
# 0.36666666666666664
# 0.38333333333333336
# 0.3333333333333333
# 0.36666666666666664
# 0.3333333333333333
# 0.36666666666666664
# 0.3333333333333333
# 0.31666666666666665
# 0.31666666666666665
# 0.31666666666666665
# 0.2833333333333333
# 0.3
# 0.25
# 0.26666666666666666
# 0.3
# 0.25
# 0.2833333333333333
# 0.3333333333333333
# 0.21666666666666667
# 0.3
# 0.3333333333333333
# 0.3
# 0.2833333333333333
# 0.3
# 0.2833333333333333
# 0.3
# 0.3
# 0.31666666666666665
# 0.35
# 0.3
# 0.26666666666666666
# 0.3
# 0.2833333333333333
# 0.2833333333333333
# 0.3
# 0.31666666666666665
# 0.26666666666666666
# 0.36666666666666664
# 0.3

# %%
knn.score(x_test,y_test)
# Out:
# 0.36666666666666664

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.svm import SVC
y=y.ravel()
model=SVC(kernel="poly")
model.fit(x_train,y_train)
# Out:
# SVC(kernel='poly')

# %%
model.score(x_test,y_test)
# Out:
# 0.36666666666666664

# %%
model.fit(x_train, y_train).score(x_train, y_train)
# Out:
# 0.48333333333333334

# %%
from sklearn.svm import SVC
model=SVC(kernel="poly")
model.fit(x_train,y_train)
# Out:
# SVC(kernel='poly')

# %%
model.score(x_test,y_test)
# Out:
# 0.36666666666666664

# %%
model.fit(x_train, y_train).score(x_train, y_train)
# Out:
# 0.48333333333333334

# %%
from sklearn.model_selection import KFold
kfold_validation=KFold(75)

# %%
model_kfold=SVC(kernel="poly")
x=sc.fit_transform(x)

# %%
from sklearn.model_selection import cross_val_score

results=cross_val_score(model_kfold,x,y,cv=kfold_validation)
print(results,'->')
# Out:
# [0.25 0.   0.5  0.   0.25 0.25 0.25 0.   0.5  0.5  0.25 0.25 0.25 0.5
#  0.   0.   1.   0.25 0.25 0.5  0.5  0.25 0.   0.   0.25 0.5  0.5  0.25
#  0.75 0.5  0.75 1.   0.   0.5  0.25 0.   0.5  0.5  0.25 0.   0.25 0.5
#  0.5  0.5  0.25 0.25 0.25 0.5  0.   0.25 0.25 0.5  0.5  0.25 0.5  0.75
#  0.   0.25 0.25 0.   0.   0.5  0.   0.5  0.5  0.25 0.25 0.25 0.5  0.5
#  0.25 0.5  0.25 0.   0.25] ->

# %%
print(np.mean(results))
# Out:
# 0.32

# %%
from sklearn.model_selection import LeaveOneOut
leave_validation=LeaveOneOut()
results=cross_val_score(model_kfold,x,y,cv=leave_validation)

# %%
x=data.iloc[:,1:]
y=data.iloc[:,:1]
l=['Gender','Vehicle_Type','Road_Type','Alcohol_Consumption','Crash_Type','Seatbelt_Usage','Road_Surface_Condition']
for i in l:
    print(i,data[i].unique())
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df=pd.DataFrame()
for i in l:
    df[i]=encoder.fit_transform(x[i])
x=x.drop(l,axis='columns')
x=pd.concat([x,df],axis='columns')
# Out:
# Gender ['Male' 'Female']
# Vehicle_Type ['Heavy Vehicle' 'Car' 'T.W']
# Road_Type ['Urban' 'Rural']
# Alcohol_Consumption ['Yes' 'No']
# Crash_Type ['Rear-end' 'Head-on']
# Seatbelt_Usage ['No' 'Yes']
# Road_Surface_Condition ['Icy' 'Dry' 'Wet']

# %%
x
# Out:
#      Vehicle_Speed  Crash_Time  Age  Number_of_Lanes  Lane_Width  Speed_Limit  \
# 0              107          11   27                2    3.484386           30
# 1               27          16   39                2    3.293091          110
# 2               87          14   42                3    3.218911           59
# 3               43           3   60                2    3.113012           73
# 4               72           8   70                3    3.106580           42
# ..             ...         ...  ...              ...         ...          ...
# 295            112           4   30                1    3.248476          118
# 296             87          21   52                2    3.037739           38
# 297             85          20   79                2    3.350668           80
# 298             44           5   23                3    3.419304           47
# 299             68          12   30                1    3.357638          120
#
# ...

# %%
x=x.iloc[:200,:]

# %%
x
# Out:
#      Vehicle_Speed  Crash_Time  Age  Number_of_Lanes  Lane_Width  Speed_Limit  \
# 0              107          11   27                2    3.484386           30
# 1               27          16   39                2    3.293091          110
# 2               87          14   42                3    3.218911           59
# 3               43           3   60                2    3.113012           73
# 4               72           8   70                3    3.106580           42
# ..             ...         ...  ...              ...         ...          ...
# 195             64           9   23                3    3.486475           76
# 196             31          15   79                2    3.404111           40
# 197             67           1   26                3    3.407907           45
# 198             80          14   56                2    3.284136           61
# 199             47           2   77                2    3.469736           72
#
# ...

# %%
y=y.iloc[:200,:]

# %%
from sklearn.model_selection import cross_val_score
results=cross_val_score(model_kfold,x,y,cv=kfold_validation)
y=y.ravel()
print(results)
# Out:
# C:\Users\vepad\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\vepad\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\vepad\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
print(np.mean(results))

# %%
len(y)
# Out:
# 300
