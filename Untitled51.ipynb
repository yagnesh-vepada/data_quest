# %%
import numpy as np
import pandas as pd
data=pd.read_excel("Data Sheet.xlsx")
data.head()
# Out:
#   Crash_Severity  Vehicle_Speed  Crash_Time  Age  Gender   Vehicle_Type  \
# 0   Minor injury            107          11   27    Male  Heavy Vehicle
# 1   Minor injury             27          16   39    Male            Car
# 2   Minor injury             87          14   42  Female            Car
# 3   Minor injury             43           3   60  Female  Heavy Vehicle
# 4   Minor injury             72           8   70    Male            T.W
#
#    Number_of_Lanes  Lane_Width Road_Type Alcohol_Consumption Crash_Type  \
# 0                2    3.484386     Urban                 Yes   Rear-end
# 1                2    3.293091     Rural                 Yes   Rear-end
# 2                3    3.218911     Urban                  No   Rear-end
# 3                2    3.113012     Rural                  No   Rear-end
# 4                3    3.106580     Urban                 Yes   Rear-end
#
#   Seatbelt_Usage  Speed_Limit Road_Surface_Condition
# ...

# %%
x=data.iloc[:,1:]
y=data.iloc[:,:1]

# %%
from sklearn.preprocessing import LabelEncoder
l=['Gender','Vehicle_Type','Road_Type','Alcohol_Consumption','Crash_Type','Seatbelt_Usage','Road_Surface_Condition']
encoder=LabelEncoder()
df=pd.DataFrame()
for i in l:
    df[i]=encoder.fit_transform(x[i])
x=x.drop(l,axis='columns')
x=pd.concat([x,df],axis='columns')

# %%
x
# Out:
#      Vehicle_Speed  Crash_Time  Age  Number_of_Lanes  Lane_Width  Speed_Limit  \
# 0              107          11   27                2    3.484386           30
# 1               27          16   39                2    3.293091          110
# 2               87          14   42                3    3.218911           59
# 3               43           3   60                2    3.113012           73
# 4               72           8   70                3    3.106580           42
# ..             ...         ...  ...              ...         ...          ...
# 295            112           4   30                1    3.248476          118
# 296             87          21   52                2    3.037739           38
# 297             85          20   79                2    3.350668           80
# 298             44           5   23                3    3.419304           47
# 299             68          12   30                1    3.357638          120
#
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# C:\Users\vepad\anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier()

# %%
y_prd=rf.predict(x_test)

# %%
rf.score(x_test,y_test)
# Out:
# 0.32

# %%
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=0)
cross_val_score(clf,x_test,y_test,  cv=10)
# Out:
# array([0.125     , 0.5       , 0.25      , 0.375     , 0.25      ,
#        0.28571429, 0.28571429, 0.28571429, 0.42857143, 0.        ])

# %%
x
# Out:
#      Vehicle_Speed  Crash_Time  Age  Number_of_Lanes  Lane_Width  Speed_Limit  \
# 0              107          11   27                2    3.484386           30
# 1               27          16   39                2    3.293091          110
# 2               87          14   42                3    3.218911           59
# 3               43           3   60                2    3.113012           73
# 4               72           8   70                3    3.106580           42
# ..             ...         ...  ...              ...         ...          ...
# 295            112           4   30                1    3.248476          118
# 296             87          21   52                2    3.037739           38
# 297             85          20   79                2    3.350668           80
# 298             44           5   23                3    3.419304           47
# 299             68          12   30                1    3.357638          120
#
# ...

# %%
import numpy as np
import pandas as pd
dataset=pd.read_excel("Data Sheet.xlsx")

dataset.head()
# Out:
#   Crash_Severity  Vehicle_Speed  Crash_Time  Age  Gender   Vehicle_Type  \
# 0   Minor injury            107          11   27    Male  Heavy Vehicle
# 1   Minor injury             27          16   39    Male            Car
# 2   Minor injury             87          14   42  Female            Car
# 3   Minor injury             43           3   60  Female  Heavy Vehicle
# 4   Minor injury             72           8   70    Male            T.W
#
#    Number_of_Lanes  Lane_Width Road_Type Alcohol_Consumption Crash_Type  \
# 0                2    3.484386     Urban                 Yes   Rear-end
# 1                2    3.293091     Rural                 Yes   Rear-end
# 2                3    3.218911     Urban                  No   Rear-end
# 3                2    3.113012     Rural                  No   Rear-end
# 4                3    3.106580     Urban                 Yes   Rear-end
#
#   Seatbelt_Usage  Speed_Limit Road_Surface_Condition
# ...

# %%
x=x.drop(l,axis='columns')

# %%
df
dataset=pd.concat([x,df],axis='columns')

# %%
dataset
# Out:
#     Crash_Severity  Vehicle_Speed  Crash_Time  Age  Gender   Vehicle_Type  \
# 0     Minor injury            107          11   27    Male  Heavy Vehicle
# 1     Minor injury             27          16   39    Male            Car
# 2     Minor injury             87          14   42  Female            Car
# 3     Minor injury             43           3   60  Female  Heavy Vehicle
# 4     Minor injury             72           8   70    Male            T.W
# ..             ...            ...         ...  ...     ...            ...
# 295    Fatal crash            112           4   30    Male            Car
# 296    Fatal crash             87          21   52  Female  Heavy Vehicle
# 297    Fatal crash             85          20   79  Female  Heavy Vehicle
# 298    Fatal crash             44           5   23  Female            Car
# 299    Fatal crash             68          12   30    Male            Car
#
#      Number_of_Lanes  Lane_Width Road_Type Alcohol_Consumption Crash_Type  \
# ...

# %%
import seaborn as sns
sns.pairplot(x_train,hue=y_train)

# %%
dataset=pd.concat([x,y],axis='columns')

# %%
import seaborn as sns
sns.pairplot(dataset,hue="Crash_Severity")

# %%
x
# Out:
#      Vehicle_Speed  Crash_Time  Age  Number_of_Lanes  Lane_Width  Speed_Limit  \
# 0              107          11   27                2    3.484386           30
# 1               27          16   39                2    3.293091          110
# 2               87          14   42                3    3.218911           59
# 3               43           3   60                2    3.113012           73
# 4               72           8   70                3    3.106580           42
# ..             ...         ...  ...              ...         ...          ...
# 295            112           4   30                1    3.248476          118
# 296             87          21   52                2    3.037739           38
# 297             85          20   79                2    3.350668           80
# 298             44           5   23                3    3.419304           47
# 299             68          12   30                1    3.357638          120
#
# ...

# %%
y
# Out:
#     Crash_Severity
# 0     Minor injury
# 1     Minor injury
# 2     Minor injury
# 3     Minor injury
# 4     Minor injury
# ..             ...
# 295    Fatal crash
# 296    Fatal crash
# 297    Fatal crash
# 298    Fatal crash
# 299    Fatal crash
#
# [300 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=10)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=10)

# %%
knn.fit(x_train,y_train)
# Out:
# C:\Users\vepad\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:238: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(n_neighbors=10)

# %%
pred=knn.predict(x_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[12  9  7]
#  [13  9 12]
#  [ 6 10 12]]

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#  Fatal crash       0.39      0.43      0.41        28
# Major injury       0.32      0.26      0.29        34
# Minor injury       0.39      0.43      0.41        28
#
#     accuracy                           0.37        90
#    macro avg       0.37      0.37      0.37        90
# weighted avg       0.36      0.37      0.36        90

# %%
error_rate=[]
y_train = y_train.values.ravel()  # Converts DataFrame to NumPy array and flattens it
y_test = y_test.values.ravel()
for i in range(1,30):
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train,y_train)
    pred_i=knn.predict(x_test)
    error_rate.append(np.mean(pred_i!=y_test))

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.plot(range(1,30),error_rate,color='blue',linestyle='dashed',marker='o')

# %%
knn.score(x_test,y_test)
# Out:
# 0.2777777777777778

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)

# %%
model=SVC()

# %%
model.fit(x_train,y_train)
# Out:
# C:\Users\vepad\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(gamma=10)

# %%
model.score(x_test,y_test)
# Out:
# 0.2833333333333333

# %%
for i in range(5):
    model=SVC(gamma=i)
    model.fit(x_train,y_train)
    print(model.score(x_test,y_test))
# Out:
# 0.2833333333333333
# 0.2833333333333333
# 0.2833333333333333
# 0.2833333333333333
# 0.2833333333333333
# C:\Users\vepad\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\vepad\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\vepad\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
model=SVC()

# %%
abc=AdaBoostClassifier(n_estimators=20,estimator=model,algorithm='SAMME')

# %%
model=abc.fit(x_train,y_train)
# Out:
# C:\Users\vepad\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
pred=model.predict(x_test)
print(confusion_matrix(y_test,pred))
# Out:
# [[ 0  0 20]
#  [ 0  0 23]
#  [ 0  0 17]]

# %%
x_test
# Out:
#      Vehicle_Speed  Crash_Time  Age  Number_of_Lanes  Lane_Width  Speed_Limit  \
# 24              87          20   68                3    3.443541           82
# 65              57          23   18                2    3.044026           33
# 113            114           2   24                1    3.193004          113
# 261             68          18   64                3    3.179160           91
# 188             26           5   54                1    3.060804           69
# 181             58           0   69                1    3.469002           66
# 59              48           5   46                3    3.105862           89
# 87              33          19   37                1    3.207594           33
# 293             46           3   51                3    3.478685           54
# 277            109          19   29                3    3.226601           37
# 244             53           1   30                3    3.147241           52
# ...

# %%
y_test
# Out:
#     Crash_Severity
# 24    Minor injury
# 65    Minor injury
# 113   Major injury
# 261    Fatal crash
# 188   Major injury
# 181   Major injury
# 59    Minor injury
# 87    Minor injury
# 293    Fatal crash
# 277    Fatal crash
# 244    Fatal crash
# 43    Minor injury
# 193   Major injury
# 284    Fatal crash
# 238    Fatal crash
# 26    Minor injury
# 245    Fatal crash
# 214    Fatal crash
# 189   Major injury
# 281    Fatal crash
# 52    Minor injury
# 215    Fatal crash
# 130   Major injury
# 64    Minor injury
# 164   Major injury
# 70    Minor injury
# 138   Major injury
# 202    Fatal crash
# 230    Fatal crash
# 132   Major injury
# 47    Minor injury
# 151   Major injury
# 25    Minor injury
# 183   Major injury
# 197   Major injury
# 298    Fatal crash
# 276    Fatal crash
# 98    Minor injury
# 231    Fatal crash
# 76    Minor injury
# 129   Major injury
# 167   Major injury
# 270    Fatal crash
# 100   Major injury
# 191   Major injury
# 199   Major injury
# ...
