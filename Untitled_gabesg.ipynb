# %%
import numpy as np
import pandas as pd
import sklearn

# %%
df = pd.read_csv('Data.csv')
# df = df.drop('Speed_Limit',axis=1)
# df = df.drop('Number_of_Lanes',axis=1)
# df = df.drop('Road_Type',axis=1)
#df = df.drop('Lane_Width',axis=1)

df
# drop number_of_lines, speed_limit, number_of_lanes
# vehucle_type, seatbelt usage....more importance,
# Out:
#     Crash_Severity  Vehicle_Speed  Crash_Time  Age  Gender   Vehicle_Type  \
# 0     Minor injury            107          11   27    Male  Heavy Vehicle
# 1     Minor injury             27          16   39    Male            Car
# 2     Minor injury             87          14   42  Female            Car
# 3     Minor injury             43           3   60  Female  Heavy Vehicle
# 4     Minor injury             72           8   70    Male            T.W
# ..             ...            ...         ...  ...     ...            ...
# 295    Fatal crash            112           4   30    Male            Car
# 296    Fatal crash             87          21   52  Female  Heavy Vehicle
# 297    Fatal crash             85          20   79  Female  Heavy Vehicle
# 298    Fatal crash             44           5   23  Female            Car
# 299    Fatal crash             68          12   30    Male            Car
#
#      Number_of_Lanes  Lane_Width Road_Type Alcohol_Consumption Crash_Type  \
# ...

# %%
df.describe()
# Out:
#        Vehicle_Speed  Crash_Time         Age  Number_of_Lanes  Lane_Width  \
# count     300.000000  300.000000  300.000000       300.000000  300.000000
# mean       64.366667   11.690000   48.663333         2.000000    3.272374
# std        31.951974    6.740327   18.432104         0.825999    0.143053
# min        10.000000    0.000000   18.000000         1.000000    3.001781
# 25%        37.000000    5.750000   31.000000         1.000000    3.150568
# 50%        60.500000   12.000000   51.000000         2.000000    3.285620
# 75%        94.000000   17.000000   65.000000         3.000000    3.394545
# max       120.000000   23.000000   80.000000         3.000000    3.497986
#
#        Speed_Limit
# count   300.000000
# mean     74.746667
# std      26.857903
# min      30.000000
# 25%      51.000000
# 50%      75.000000
# 75%      97.250000
# max     120.000000

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, auc, roc_curve
from sklearn.metrics import classification_report, precision_score, recall_score

label_encoders = {} # to encode the classes into integers, as classes

for column in df.select_dtypes(include=['object']).columns:
    label_encoders[column] = LabelEncoder()
    df[column] = label_encoders[column].fit_transform(df[column])
    
for i in list(label_encoders.keys()):
  classes = label_encoders[i].classes_
  encoding_dict = {class_label: index for index, class_label in enumerate(classes)}
  print(i,encoding_dict)
# Out:
# Crash_Severity {'Fatal crash': 0, 'Major injury': 1, 'Minor injury': 2}
# Gender {'Female': 0, 'Male': 1}
# Vehicle_Type {'Car': 0, 'Heavy Vehicle': 1, 'T.W': 2}
# Road_Type {'Rural': 0, 'Urban': 1}
# Alcohol_Consumption {'No': 0, 'Yes': 1}
# Crash_Type {'Head-on': 0, 'Rear-end': 1}
# Seatbelt_Usage {'No': 0, 'Yes': 1}
# Road_Surface_Condition {'Dry': 0, 'Icy': 1, 'Wet': 2}

# %%
df
# Out:
#      Crash_Severity  Vehicle_Speed  Crash_Time  Age  Gender  Vehicle_Type  \
# 0                 2            107          11   27       1             1
# 1                 2             27          16   39       1             0
# 2                 2             87          14   42       0             0
# 3                 2             43           3   60       0             1
# 4                 2             72           8   70       1             2
# ..              ...            ...         ...  ...     ...           ...
# 295               0            112           4   30       1             0
# 296               0             87          21   52       0             1
# 297               0             85          20   79       0             1
# 298               0             44           5   23       0             0
# 299               0             68          12   30       1             0
#
#      Number_of_Lanes  Lane_Width  Road_Type  Alcohol_Consumption  Crash_Type  \
# ...

# %%
X = df.drop('Crash_Severity',axis=1) # x is df without the label - status. x=> features
y = df['Crash_Severity'] # y only contains the label - status. y=>target

# %%
X1 = X.copy()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()


for feature in ['Vehicle_Speed', 'Crash_Time', 'Age', 'Lane_Width', 'Speed_Limit']:
  X1[feature] = scaler.fit_transform(X1[[feature]])  

X1
# Out:
#      Vehicle_Speed  Crash_Time       Age  Gender  Vehicle_Type  \
# 0         0.881818    0.478261  0.145161       1             1
# 1         0.154545    0.695652  0.338710       1             0
# 2         0.700000    0.608696  0.387097       0             0
# 3         0.300000    0.130435  0.677419       0             1
# 4         0.563636    0.347826  0.838710       1             2
# ..             ...         ...       ...     ...           ...
# 295       0.927273    0.173913  0.193548       1             0
# 296       0.700000    0.913043  0.548387       0             1
# 297       0.681818    0.869565  0.983871       0             1
# 298       0.309091    0.217391  0.080645       0             0
# 299       0.527273    0.521739  0.193548       1             0
#
#      Number_of_Lanes  Lane_Width  Road_Type  Alcohol_Consumption  Crash_Type  \
# 0                  2    0.972592          1                    1           1
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X1,y,test_size=0.09,random_state=42,shuffle=True)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# algorithm{‘auto’, ‘ball_tree’, ‘kd_tree’, ‘brute’}, default=’auto’

# %%
knn = KNeighborsClassifier(n_neighbors=4, weights='uniform')  
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.5555555555555556

# %%
import numpy as np
import pandas as pd
import sklearn
df = pd.read_csv('Data.csv')
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, auc, roc_curve
from sklearn.metrics import classification_report, precision_score, recall_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

label_encoders = {} # to encode the classes into integers, as classes

for column in df.select_dtypes(include=['object']).columns:
    label_encoders[column] = LabelEncoder()
    df[column] = label_encoders[column].fit_transform(df[column])
    
for i in list(label_encoders.keys()):
  classes = label_encoders[i].classes_
  encoding_dict = {class_label: index for index, class_label in enumerate(classes)}
  print(i,encoding_dict)

X = df.drop('Crash_Severity',axis=1) # x is df without the label - status. x=> features
y = df['Crash_Severity'] # y only contains the label - status. y=>target

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()


for feature in ['Vehicle_Speed', 'Crash_Time', 'Age', 'Lane_Width', 'Speed_Limit']:
  X1[feature] = scaler.fit_transform(X1[[feature]])  

X_train, X_test, y_train, y_test = train_test_split(X1,y,test_size=0.09,random_state=42,shuffle=True)
knn = KNeighborsClassifier(n_neighbors=4, weights='uniform')  
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:",accuracy)

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier

# Load data
df = pd.read_csv('Data.csv')

# Encode categorical variables
label_encoders = {}
for column in df.select_dtypes(include=['object']).columns:
    label_encoders[column] = LabelEncoder()
    df[column] = label_encoders[column].fit_transform(df[column])

# Display encoding information
for i in list(label_encoders.keys()):
    classes = label_encoders[i].classes_
    encoding_dict = {class_label: index for index, class_label in enumerate(classes)}
    print(i, encoding_dict)

# Define features and target
X = df.drop('Crash_Severity', axis=1)
y = df['Crash_Severity']

# Scale selected numerical features
scaler = MinMaxScaler()
X_scaled = X.copy()  # Copy original X to preserve structure
numerical_features = ['Vehicle_Speed', 'Crash_Time', 'Age', 'Lane_Width', 'Speed_Limit']
X_scaled[numerical_features] = scaler.fit_transform(X[numerical_features])

# Apply PCA for dimensionality reduction
pca = PCA(n_components=0.95)  # Retain 95% of variance
X_pca = pca.fit_transform(X_scaled)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.09, random_state=42, shuffle=True)

# Train KNN classifier
knn = KNeighborsClassifier(n_neighbors=4, weights='uniform')
knn.fit(X_train, y_train)

# Predict and evaluate
y_pred = knn.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("Classification Report:\n", classification_report(y_test, y_pred))

# Optional: Check explained variance ratio
print("Explained Variance Ratio:", pca.explained_variance_ratio_)
# Out:
# Crash_Severity {'Fatal crash': 0, 'Major injury': 1, 'Minor injury': 2}
# Gender {'Female': 0, 'Male': 1}
# Vehicle_Type {'Car': 0, 'Heavy Vehicle': 1, 'T.W': 2}
# Road_Type {'Rural': 0, 'Urban': 1}
# Alcohol_Consumption {'No': 0, 'Yes': 1}
# Crash_Type {'Head-on': 0, 'Rear-end': 1}
# Seatbelt_Usage {'No': 0, 'Yes': 1}
# Road_Surface_Condition {'Dry': 0, 'Icy': 1, 'Wet': 2}
# Accuracy: 0.5925925925925926
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70        12
#            1       0.50      0.44      0.47         9
#            2       0.50      0.67      0.57         6
#
#     accuracy                           0.59        27
#    macro avg       0.58      0.59      0.58        27
# weighted avg       0.60      0.59      0.59        27
#
# Explained Variance Ratio: [0.18889407 0.18625355 0.17761435 0.08167625 0.07252013 0.0687932
#  0.06018439 0.05184071 0.02655133 0.02400018 0.02320242]

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.neighbors import KNeighborsClassifier

# Load data
df = pd.read_csv('Data.csv')

# Encode categorical variables
label_encoders = {}
for column in df.select_dtypes(include=['object']).columns:
    label_encoders[column] = LabelEncoder()
    df[column] = label_encoders[column].fit_transform(df[column])

# Display encoding information
for i in list(label_encoders.keys()):
    classes = label_encoders[i].classes_
    encoding_dict = {class_label: index for index, class_label in enumerate(classes)}
    print(i, encoding_dict)

# Define features and target
X = df.drop('Crash_Severity', axis=1)
y = df['Crash_Severity']

# Scale selected numerical features
scaler = MinMaxScaler()
X_scaled = X.copy()  # Copy original X to preserve structure
numerical_features = ['Vehicle_Speed', 'Crash_Time', 'Age', 'Lane_Width', 'Speed_Limit']
X_scaled[numerical_features] = scaler.fit_transform(X[numerical_features])

# Apply LDA for dimensionality reduction
lda = LDA(n_components=2)  # Reduce to 2 components
X_lda = lda.fit_transform(X_scaled, y)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_lda, y, test_size=0.09, random_state=42, shuffle=True)

# Train KNN classifier
knn = KNeighborsClassifier(n_neighbors=4, weights='uniform')
knn.fit(X_train, y_train)

# Predict and evaluate
y_pred = knn.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Crash_Severity {'Fatal crash': 0, 'Major injury': 1, 'Minor injury': 2}
# Gender {'Female': 0, 'Male': 1}
# Vehicle_Type {'Car': 0, 'Heavy Vehicle': 1, 'T.W': 2}
# Road_Type {'Rural': 0, 'Urban': 1}
# Alcohol_Consumption {'No': 0, 'Yes': 1}
# Crash_Type {'Head-on': 0, 'Rear-end': 1}
# Seatbelt_Usage {'No': 0, 'Yes': 1}
# Road_Surface_Condition {'Dry': 0, 'Icy': 1, 'Wet': 2}
# Accuracy: 0.5555555555555556
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.33      0.44        12
#            1       0.50      0.67      0.57         9
#            2       0.56      0.83      0.67         6
#
#     accuracy                           0.56        27
#    macro avg       0.57      0.61      0.56        27
# weighted avg       0.59      0.56      0.54        27

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE
from sklearn.neighbors import KNeighborsClassifier

# Load data
df = pd.read_csv('Data.csv')

# Encode categorical variables
label_encoders = {}
for column in df.select_dtypes(include=['object']).columns:
    label_encoders[column] = LabelEncoder()
    df[column] = label_encoders[column].fit_transform(df[column])

# Display encoding information
for i in list(label_encoders.keys()):
    classes = label_encoders[i].classes_
    encoding_dict = {class_label: index for index, class_label in enumerate(classes)}
    print(i, encoding_dict)

# Define features and target
X = df.drop('Crash_Severity', axis=1)
y = df['Crash_Severity']

# Scale selected numerical features
scaler = MinMaxScaler()
X_scaled = X.copy()  # Copy original X to preserve structure
numerical_features = ['Vehicle_Speed', 'Crash_Time', 'Age', 'Lane_Width', 'Speed_Limit']
X_scaled[numerical_features] = scaler.fit_transform(X[numerical_features])

# Apply t-SNE for dimensionality reduction
tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(X_scaled)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_tsne, y, test_size=0.09, random_state=42, shuffle=True)

# Train KNN classifier
knn = KNeighborsClassifier(n_neighbors=4, weights='uniform')
knn.fit(X_train, y_train)

# Predict and evaluate
y_pred = knn.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Crash_Severity {'Fatal crash': 0, 'Major injury': 1, 'Minor injury': 2}
# Gender {'Female': 0, 'Male': 1}
# Vehicle_Type {'Car': 0, 'Heavy Vehicle': 1, 'T.W': 2}
# Road_Type {'Rural': 0, 'Urban': 1}
# Alcohol_Consumption {'No': 0, 'Yes': 1}
# Crash_Type {'Head-on': 0, 'Rear-end': 1}
# Seatbelt_Usage {'No': 0, 'Yes': 1}
# Road_Surface_Condition {'Dry': 0, 'Icy': 1, 'Wet': 2}
# Accuracy: 0.4074074074074074
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.56      0.42      0.48        12
#            1       0.38      0.33      0.35         9
#            2       0.30      0.50      0.38         6
#
#     accuracy                           0.41        27
#    macro avg       0.41      0.42      0.40        27
# weighted avg       0.44      0.41      0.41        27

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE
from sklearn.neighbors import KNeighborsClassifier

# Load data
df = pd.read_csv('Data.csv')

# Encode categorical variables
label_encoders = {}
for column in df.select_dtypes(include=['object']).columns:
    label_encoders[column] = LabelEncoder()
    df[column] = label_encoders[column].fit_transform(df[column])

# Display encoding information
for i in list(label_encoders.keys()):
    classes = label_encoders[i].classes_
    encoding_dict = {class_label: index for index, class_label in enumerate(classes)}
    print(i, encoding_dict)

# Define features and target
X = df.drop('Crash_Severity', axis=1)
y = df['Crash_Severity']

# Scale selected numerical features
scaler = MinMaxScaler()
X_scaled = X.copy()  # Copy original X to preserve structure
numerical_features = ['Vehicle_Speed', 'Crash_Time', 'Age', 'Lane_Width', 'Speed_Limit']
X_scaled[numerical_features] = scaler.fit_transform(X[numerical_features])

# Apply t-SNE for dimensionality reduction
tsne = TSNE(n_components=3, random_state=42)
X_tsne = tsne.fit_transform(X_scaled)

# 2D t-SNE Plot
plt.figure(figsize=(8, 6))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y, cmap='viridis', s=10, alpha=0.7)
plt.colorbar(label='Crash Severity')
plt.title('2D t-SNE Visualization of Crash Severity')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.show()

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_tsne, y, test_size=0.09, random_state=42, shuffle=True)

# Train KNN classifier
knn = KNeighborsClassifier(n_neighbors=4, weights='uniform')
knn.fit(X_train, y_train)

# Predict and evaluate
y_pred = knn.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Crash_Severity {'Fatal crash': 0, 'Major injury': 1, 'Minor injury': 2}
# Gender {'Female': 0, 'Male': 1}
# Vehicle_Type {'Car': 0, 'Heavy Vehicle': 1, 'T.W': 2}
# Road_Type {'Rural': 0, 'Urban': 1}
# Alcohol_Consumption {'No': 0, 'Yes': 1}
# Crash_Type {'Head-on': 0, 'Rear-end': 1}
# Seatbelt_Usage {'No': 0, 'Yes': 1}
# Road_Surface_Condition {'Dry': 0, 'Icy': 1, 'Wet': 2}
# Accuracy: 0.4074074074074074
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.57      0.33      0.42        12
#            1       0.33      0.44      0.38         9
#            2       0.38      0.50      0.43         6
#
#     accuracy                           0.41        27
#    macro avg       0.43      0.43      0.41        27
# weighted avg       0.45      0.41      0.41        27

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,shuffle=True)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE
from sklearn.neighbors import KNeighborsClassifier

# Load data
df = pd.read_csv('Data.csv')

# Encode categorical variables
label_encoders = {}
for column in df.select_dtypes(include=['object']).columns:
    label_encoders[column] = LabelEncoder()
    df[column] = label_encoders[column].fit_transform(df[column])

# Display encoding information
for i in list(label_encoders.keys()):
    classes = label_encoders[i].classes_
    encoding_dict = {class_label: index for index, class_label in enumerate(classes)}
    print(i, encoding_dict)

# Define features and target
X = df.drop('Crash_Severity', axis=1)
y = df['Crash_Severity']

# Scale selected numerical features
scaler = MinMaxScaler()
X_scaled = X.copy()  # Copy original X to preserve structure
numerical_features = ['Vehicle_Speed', 'Crash_Time', 'Age', 'Lane_Width', 'Speed_Limit']
X_scaled[numerical_features] = scaler.fit_transform(X[numerical_features])

# Apply t-SNE for 3D dimensionality reduction
tsne = TSNE(n_components=3, random_state=42)
X_tsne = tsne.fit_transform(X_scaled)

# Plot 3D t-SNE
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(X_tsne[:, 0], X_tsne[:, 1], X_tsne[:, 2], c=y, cmap='viridis', s=50)
legend1 = ax.legend(*scatter.legend_elements(), title="Classes")
ax.add_artist(legend1)
ax.set_title("3D t-SNE Visualization")
ax.set_xlabel("t-SNE Component 1")
ax.set_ylabel("t-SNE Component 2")
ax.set_zlabel("t-SNE Component 3")
plt.show()

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_tsne, y, test_size=0.09, random_state=42, shuffle=True)

# Train KNN classifier
knn = KNeighborsClassifier(n_neighbors=4, weights='uniform')
knn.fit(X_train, y_train)

# Predict and evaluate
y_pred = knn.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Crash_Severity {'Fatal crash': 0, 'Major injury': 1, 'Minor injury': 2}
# Gender {'Female': 0, 'Male': 1}
# Vehicle_Type {'Car': 0, 'Heavy Vehicle': 1, 'T.W': 2}
# Road_Type {'Rural': 0, 'Urban': 1}
# Alcohol_Consumption {'No': 0, 'Yes': 1}
# Crash_Type {'Head-on': 0, 'Rear-end': 1}
# Seatbelt_Usage {'No': 0, 'Yes': 1}
# Road_Surface_Condition {'Dry': 0, 'Icy': 1, 'Wet': 2}
# Accuracy: 0.4074074074074074
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.57      0.33      0.42        12
#            1       0.33      0.44      0.38         9
#            2       0.38      0.50      0.43         6
#
#     accuracy                           0.41        27
#    macro avg       0.43      0.43      0.41        27
# weighted avg       0.45      0.41      0.41        27

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn import svm
clf = make_pipeline(StandardScaler(), SVC())

# %%
clf = svm.SVC(kernel='linear',C=5, class_weight='balanced', decision_function_shape='ovr')
clf.fit(X_train, y_train)

# %%
y_predict = clf.predict(X_test)
print(confusion_matrix(y_test,y_predict))
print(classification_report(y_test,y_predict))

# %%
model = RandomForestClassifier(random_state=42, n_estimators=10, criterion='entropy', max_depth=5, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='sqrt') #general model

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB,CategoricalNB
model = CategoricalNB()
y_pred = model.fit(X_train, y_train).predict(X_test)
print("Number of mislabeled points out of a total %d points : %d"
      % (X_test.shape[0], (y_test != y_pred).sum()))

# %%
 model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("Accuracy: ",accuracy_score(y_test,y_pred))
print("Precision: ",precision_score(y_test,y_pred))
print("Recall: ",recall_score(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=3)

# %%
pca.fit(X)

# %%
pca.transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,shuffle=True)
