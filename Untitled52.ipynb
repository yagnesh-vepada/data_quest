# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
data=pd.read_excel("Data Sheet.xlsx")

# %%
x=data.iloc[:,1:]
y=data.iloc[:,:1]

# %%
l=['Gender','Vehicle_Type','Road_Type','Alcohol_Consumption','Crash_Type','Seatbelt_Usage','Road_Surface_Condition']
for i in l:
    print(i,data[i].unique())
# Out:
# Gender ['Male' 'Female']
# Vehicle_Type ['Heavy Vehicle' 'Car' 'T.W']
# Road_Type ['Urban' 'Rural']
# Alcohol_Consumption ['Yes' 'No']
# Crash_Type ['Rear-end' 'Head-on']
# Seatbelt_Usage ['No' 'Yes']
# Road_Surface_Condition ['Icy' 'Dry' 'Wet']

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df=pd.DataFrame()
for i in l:
    df[i]=encoder.fit_transform(x[i])

# %%
x=x.drop(l,axis='columns')

# %%
x=pd.concat([x,df],axis='columns')

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
from sklearn.svm import SVC
model=SVC()

# %%
model.fit(x_train,y_train)
# Out:
# C:\Users\vepad\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC()

# %%
model.predict(x_test)
# Out:
# array(['Minor injury', 'Fatal crash', 'Minor injury', 'Major injury',
#        'Fatal crash', 'Fatal crash', 'Minor injury', 'Fatal crash',
#        'Minor injury', 'Major injury', 'Major injury', 'Fatal crash',
#        'Minor injury', 'Minor injury', 'Minor injury', 'Minor injury',
#        'Minor injury', 'Minor injury', 'Fatal crash', 'Major injury',
#        'Minor injury', 'Minor injury', 'Major injury', 'Minor injury',
#        'Fatal crash', 'Fatal crash', 'Minor injury', 'Fatal crash',
#        'Minor injury', 'Minor injury', 'Major injury', 'Minor injury',
#        'Major injury', 'Minor injury', 'Minor injury', 'Major injury',
#        'Minor injury', 'Minor injury', 'Minor injury', 'Major injury',
#        'Fatal crash', 'Major injury', 'Major injury', 'Fatal crash',
#        'Fatal crash', 'Fatal crash', 'Major injury', 'Minor injury',
#        'Minor injury', 'Fatal crash', 'Fatal crash', 'Minor injury',
#        'Fatal crash', 'Fatal crash', 'Fatal crash', 'Major injury',
#        'Major injury', 'Major injury', 'Major injury', 'Fatal crash'],
#       dtype=object)

# %%
model.score(x_test,y_test)
# Out:
# 0.31666666666666665

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=0)
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
from sklearn import tree
plt.figure(figsize=(10,15))
tree.plot_tree(clf,filled=True)
# Out:
# [Text(0.5202574118589743, 0.9722222222222222, 'x[4] <= -1.66\ngini = 0.667\nsamples = 240\nvalue = [80, 80, 80]'),
#  Text(0.26061698717948717, 0.9166666666666666, 'x[0] <= -1.069\ngini = 0.439\nsamples = 14\nvalue = [10, 1, 3]'),
#  Text(0.3904371995192307, 0.9444444444444444, 'True  '),
#  Text(0.23497596153846154, 0.8611111111111112, 'x[1] <= -1.603\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 3]'),
#  Text(0.2221554487179487, 0.8055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.24779647435897437, 0.8055555555555556, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.28625801282051283, 0.8611111111111112, 'x[2] <= 0.95\ngini = 0.18\nsamples = 10\nvalue = [9, 1, 0]'),
#  Text(0.2734375, 0.8055555555555556, 'gini = 0.0\nsamples = 6\nvalue = [6, 0, 0]'),
#  Text(0.29907852564102566, 0.8055555555555556, 'x[1] <= -0.056\ngini = 0.375\nsamples = 4\nvalue = [3, 1, 0]'),
#  Text(0.28625801282051283, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.31189903846153844, 0.75, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0]'),
#  Text(0.7798978365384616, 0.9166666666666666, 'x[4] <= 1.504\ngini = 0.666\nsamples = 226\nvalue = [70, 79, 77]'),
#  Text(0.650077624198718, 0.9444444444444444, '  False'),
#  Text(0.6238982371794872, 0.8611111111111112, 'x[0] <= 1.31\ngini = 0.666\nsamples = 220\nvalue = [70, 74, 76]'),
#  Text(0.3503605769230769, 0.8055555555555556, 'x[0] <= 1.247\ngini = 0.663\nsamples = 190\nvalue = [56.0, 62.0, 72.0]'),
#  Text(0.3375400641025641, 0.75, 'x[0] <= -1.648\ngini = 0.665\nsamples = 186\nvalue = [56, 62, 68]'),
#  Text(0.2075320512820513, 0.6944444444444444, 'x[2] <= 1.307\ngini = 0.32\nsamples = 5\nvalue = [4, 0, 1]'),
#  Text(0.19471153846153846, 0.6388888888888888, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(0.2203525641025641, 0.6388888888888888, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.4675480769230769, 0.6944444444444444, 'x[4] <= 0.423\ngini = 0.663\nsamples = 181\nvalue = [52, 62, 67]'),
#  Text(0.24599358974358973, 0.6388888888888888, 'x[0] <= -0.694\ngini = 0.657\nsamples = 109\nvalue = [34, 30, 45]'),
#  Text(0.10897435897435898, 0.5833333333333334, 'x[4] <= -0.189\ngini = 0.626\nsamples = 41\nvalue = [7.0, 18.0, 16.0]'),
#  Text(0.0641025641025641, 0.5277777777777778, 'x[5] <= 0.712\ngini = 0.559\nsamples = 28\nvalue = [3, 16, 9]'),
#  Text(0.038461538461538464, 0.4722222222222222, 'x[5] <= -0.167\ngini = 0.594\nsamples = 16\nvalue = [2, 6, 8]'),
#  Text(0.02564102564102564, 0.4166666666666667, 'x[1] <= -0.719\ngini = 0.595\nsamples = 11\nvalue = [2, 6, 3]'),
#  Text(0.01282051282051282, 0.3611111111111111, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0]'),
#  Text(0.038461538461538464, 0.3611111111111111, 'x[1] <= 0.385\ngini = 0.653\nsamples = 7\nvalue = [2, 2, 3]'),
#  Text(0.02564102564102564, 0.3055555555555556, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.05128205128205128, 0.3055555555555556, 'x[2] <= -1.52\ngini = 0.48\nsamples = 5\nvalue = [0, 2, 3]'),
#  Text(0.038461538461538464, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.0641025641025641, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.05128205128205128, 0.4166666666666667, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5]'),
#  Text(0.08974358974358974, 0.4722222222222222, 'x[0] <= -1.523\ngini = 0.292\nsamples = 12\nvalue = [1, 10, 1]'),
#  Text(0.07692307692307693, 0.4166666666666667, 'x[11] <= 0.084\ngini = 0.625\nsamples = 4\nvalue = [1, 2, 1]'),
#  Text(0.0641025641025641, 0.3611111111111111, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.08974358974358974, 0.3611111111111111, 'x[7] <= 0.063\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1]'),
#  Text(0.07692307692307693, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.10256410256410256, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.10256410256410256, 0.4166666666666667, 'gini = 0.0\nsamples = 8\nvalue = [0, 8, 0]'),
#  Text(0.15384615384615385, 0.5277777777777778, 'x[5] <= 0.88\ngini = 0.592\nsamples = 13\nvalue = [4, 2, 7]'),
#  Text(0.14102564102564102, 0.4722222222222222, 'x[2] <= -0.889\ngini = 0.642\nsamples = 9\nvalue = [4, 2, 3]'),
#  Text(0.1282051282051282, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'x[12] <= -0.608\ngini = 0.653\nsamples = 7\nvalue = [2, 2, 3]'),
#  Text(0.14102564102564102, 0.3611111111111111, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.16666666666666666, 0.3611111111111111, 'x[6] <= 0.0\ngini = 0.64\nsamples = 5\nvalue = [2, 2, 1]'),
#  Text(0.15384615384615385, 0.3055555555555556, 'x[11] <= 0.084\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 1]'),
#  Text(0.14102564102564102, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.16666666666666666, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.1794871794871795, 0.3055555555555556, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.16666666666666666, 0.4722222222222222, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(0.38301282051282054, 0.5833333333333334, 'x[7] <= 0.688\ngini = 0.629\nsamples = 68\nvalue = [27, 12, 29]'),
#  Text(0.30448717948717946, 0.5277777777777778, 'x[12] <= -0.608\ngini = 0.571\nsamples = 49\nvalue = [22.0, 4.0, 23.0]'),
#  Text(0.23076923076923078, 0.4722222222222222, 'x[4] <= -0.948\ngini = 0.475\nsamples = 18\nvalue = [5, 1, 12]'),
#  Text(0.21794871794871795, 0.4166666666666667, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6]'),
#  Text(0.24358974358974358, 0.4166666666666667, 'x[3] <= -0.643\ngini = 0.569\nsamples = 12\nvalue = [5, 1, 6]'),
#  Text(0.21794871794871795, 0.3611111111111111, 'x[0] <= 0.214\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(0.20512820512820512, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.23076923076923078, 0.3055555555555556, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.2692307692307692, 0.3611111111111111, 'x[2] <= -0.532\ngini = 0.469\nsamples = 8\nvalue = [5, 0, 3]'),
#  Text(0.2564102564102564, 0.3055555555555556, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0]'),
#  Text(0.28205128205128205, 0.3055555555555556, 'x[0] <= 0.934\ngini = 0.48\nsamples = 5\nvalue = [2, 0, 3]'),
#  Text(0.2692307692307692, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.2948717948717949, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.3782051282051282, 0.4722222222222222, 'x[1] <= 1.343\ngini = 0.564\nsamples = 31\nvalue = [17, 3, 11]'),
#  Text(0.36538461538461536, 0.4166666666666667, 'x[5] <= -1.364\ngini = 0.59\nsamples = 27\nvalue = [13, 3, 11]'),
#  Text(0.3525641025641026, 0.3611111111111111, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.3782051282051282, 0.3611111111111111, 'x[4] <= -0.653\ngini = 0.58\nsamples = 24\nvalue = [13, 3, 8]'),
#  Text(0.3333333333333333, 0.3055555555555556, 'x[0] <= -0.662\ngini = 0.32\nsamples = 10\nvalue = [8, 0, 2]'),
#  Text(0.32051282051282054, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.34615384615384615, 0.25, 'x[10] <= -0.025\ngini = 0.198\nsamples = 9\nvalue = [8, 0, 1]'),
#  Text(0.3333333333333333, 0.19444444444444445, 'x[4] <= -1.273\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 1]'),
#  Text(0.32051282051282054, 0.1388888888888889, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.34615384615384615, 0.1388888888888889, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.358974358974359, 0.19444444444444445, 'gini = 0.0\nsamples = 6\nvalue = [6, 0, 0]'),
#  Text(0.4230769230769231, 0.3055555555555556, 'x[12] <= 0.588\ngini = 0.643\nsamples = 14\nvalue = [5, 3, 6]'),
#  Text(0.3974358974358974, 0.25, 'x[4] <= -0.59\ngini = 0.32\nsamples = 5\nvalue = [4, 0, 1]'),
#  Text(0.38461538461538464, 0.19444444444444445, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.41025641025641024, 0.19444444444444445, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(0.44871794871794873, 0.25, 'x[1] <= -1.309\ngini = 0.568\nsamples = 9\nvalue = [1, 3, 5]'),
#  Text(0.4358974358974359, 0.19444444444444445, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.46153846153846156, 0.19444444444444445, 'x[0] <= 0.151\ngini = 0.469\nsamples = 8\nvalue = [0, 3, 5]'),
#  Text(0.44871794871794873, 0.1388888888888889, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.47435897435897434, 0.1388888888888889, 'x[1] <= -0.351\ngini = 0.48\nsamples = 5\nvalue = [0, 3, 2]'),
#  Text(0.46153846153846156, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.48717948717948717, 0.08333333333333333, 'x[0] <= 0.887\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.47435897435897434, 0.027777777777777776, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.5, 0.027777777777777776, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.391025641025641, 0.4166666666666667, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(0.46153846153846156, 0.5277777777777778, 'x[1] <= -0.646\ngini = 0.654\nsamples = 19\nvalue = [5, 8, 6]'),
#  Text(0.44871794871794873, 0.4722222222222222, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0]'),
#  Text(0.47435897435897434, 0.4722222222222222, 'x[2] <= -0.477\ngini = 0.658\nsamples = 15\nvalue = [5, 4, 6]'),
#  Text(0.44871794871794873, 0.4166666666666667, 'x[5] <= -1.102\ngini = 0.408\nsamples = 7\nvalue = [5, 0, 2]'),
#  Text(0.4358974358974359, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.3611111111111111, 'x[0] <= 0.355\ngini = 0.278\nsamples = 6\nvalue = [5, 0, 1]'),
#  Text(0.44871794871794873, 0.3055555555555556, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0]'),
#  Text(0.47435897435897434, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.5, 0.4166666666666667, 'x[1] <= -0.13\ngini = 0.5\nsamples = 8\nvalue = [0, 4, 4]'),
#  Text(0.48717948717948717, 0.3611111111111111, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.5128205128205128, 0.3611111111111111, 'x[12] <= 0.588\ngini = 0.444\nsamples = 6\nvalue = [0, 4, 2]'),
#  Text(0.5, 0.3055555555555556, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.5256410256410257, 0.3055555555555556, 'x[10] <= -0.025\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.5128205128205128, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.5384615384615384, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.6891025641025641, 0.6388888888888888, 'x[4] <= 1.146\ngini = 0.647\nsamples = 72\nvalue = [18, 32, 22]'),
#  Text(0.5769230769230769, 0.5833333333333334, 'x[5] <= -1.383\ngini = 0.622\nsamples = 47\nvalue = [15, 23, 9]'),
#  Text(0.5512820512820513, 0.5277777777777778, 'x[3] <= 0.572\ngini = 0.5\nsamples = 6\nvalue = [1, 1, 4]'),
#  Text(0.5384615384615384, 0.4722222222222222, 'x[2] <= 0.621\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 4]'),
#  Text(0.5256410256410257, 0.4166666666666667, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(0.5512820512820513, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.5641025641025641, 0.4722222222222222, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.6025641025641025, 0.5277777777777778, 'x[1] <= -1.309\ngini = 0.581\nsamples = 41\nvalue = [14.0, 22.0, 5.0]'),
#  Text(0.5897435897435898, 0.4722222222222222, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0]'),
#  Text(0.6153846153846154, 0.4722222222222222, 'x[1] <= -0.277\ngini = 0.602\nsamples = 37\nvalue = [14, 18, 5]'),
#  Text(0.5769230769230769, 0.4166666666666667, 'x[0] <= 0.339\ngini = 0.46\nsamples = 10\nvalue = [7, 2, 1]'),
#  Text(0.5641025641025641, 0.3611111111111111, 'x[4] <= 0.567\ngini = 0.219\nsamples = 8\nvalue = [7, 0, 1]'),
#  Text(0.5512820512820513, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.5769230769230769, 0.3055555555555556, 'gini = 0.0\nsamples = 7\nvalue = [7, 0, 0]'),
#  Text(0.5897435897435898, 0.3611111111111111, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.6538461538461539, 0.4166666666666667, 'x[4] <= 0.873\ngini = 0.56\nsamples = 27\nvalue = [7, 16, 4]'),
#  Text(0.6153846153846154, 0.3611111111111111, 'x[4] <= 0.529\ngini = 0.64\nsamples = 15\nvalue = [6, 6, 3]'),
#  Text(0.6025641025641025, 0.3055555555555556, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.6282051282051282, 0.3055555555555556, 'x[12] <= -0.608\ngini = 0.625\nsamples = 12\nvalue = [6, 3, 3]'),
#  Text(0.6153846153846154, 0.25, 'x[1] <= 0.901\ngini = 0.656\nsamples = 8\nvalue = [2, 3, 3]'),
#  Text(0.6025641025641025, 0.19444444444444445, 'x[2] <= 0.456\ngini = 0.5\nsamples = 6\nvalue = [0, 3, 3]'),
#  Text(0.5897435897435898, 0.1388888888888889, 'x[0] <= -0.928\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(0.5769230769230769, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.6025641025641025, 0.08333333333333333, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.6153846153846154, 0.1388888888888889, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.6282051282051282, 0.19444444444444445, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.6410256410256411, 0.25, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(0.6923076923076923, 0.3611111111111111, 'x[4] <= 1.13\ngini = 0.292\nsamples = 12\nvalue = [1, 10, 1]'),
#  Text(0.6794871794871795, 0.3055555555555556, 'x[5] <= 1.31\ngini = 0.165\nsamples = 11\nvalue = [0, 10, 1]'),
#  Text(0.6666666666666666, 0.25, 'gini = 0.0\nsamples = 10\nvalue = [0, 10, 0]'),
#  Text(0.6923076923076923, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.7051282051282052, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.8012820512820513, 0.5833333333333334, 'x[5] <= 0.113\ngini = 0.586\nsamples = 25\nvalue = [3, 9, 13]'),
#  Text(0.7692307692307693, 0.5277777777777778, 'x[1] <= 0.312\ngini = 0.541\nsamples = 14\nvalue = [1, 8, 5]'),
#  Text(0.7435897435897436, 0.4722222222222222, 'x[8] <= 0.008\ngini = 0.37\nsamples = 9\nvalue = [1, 7, 1]'),
#  Text(0.7307692307692307, 0.4166666666666667, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0]'),
#  Text(0.7564102564102564, 0.4166666666666667, 'x[7] <= 0.688\ngini = 0.625\nsamples = 4\nvalue = [1, 2, 1]'),
#  Text(0.7435897435897436, 0.3611111111111111, 'x[11] <= 0.084\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1]'),
#  Text(0.7307692307692307, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.7564102564102564, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.7692307692307693, 0.3611111111111111, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.7948717948717948, 0.4722222222222222, 'x[12] <= 0.588\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 4]'),
#  Text(0.782051282051282, 0.4166666666666667, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(0.8076923076923077, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8333333333333334, 0.5277777777777778, 'x[9] <= 0.075\ngini = 0.43\nsamples = 11\nvalue = [2, 1, 8]'),
#  Text(0.8205128205128205, 0.4722222222222222, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5]'),
#  Text(0.8461538461538461, 0.4722222222222222, 'x[6] <= 0.0\ngini = 0.611\nsamples = 6\nvalue = [2, 1, 3]'),
#  Text(0.8333333333333334, 0.4166666666666667, 'x[1] <= 1.196\ngini = 0.48\nsamples = 5\nvalue = [2, 0, 3]'),
#  Text(0.8205128205128205, 0.3611111111111111, 'x[2] <= -0.312\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 1]'),
#  Text(0.8076923076923077, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8333333333333334, 0.3055555555555556, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.8461538461538461, 0.3611111111111111, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.8589743589743589, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.36318108974358976, 0.75, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(0.8974358974358975, 0.8055555555555556, 'x[5] <= 0.656\ngini = 0.604\nsamples = 30\nvalue = [14, 12, 4]'),
#  Text(0.8461538461538461, 0.75, 'x[4] <= -0.757\ngini = 0.408\nsamples = 14\nvalue = [10, 4, 0]'),
#  Text(0.8205128205128205, 0.6944444444444444, 'x[2] <= -0.669\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0]'),
#  Text(0.8076923076923077, 0.6388888888888888, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.8333333333333334, 0.6388888888888888, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.8717948717948718, 0.6944444444444444, 'x[5] <= -0.653\ngini = 0.298\nsamples = 11\nvalue = [9, 2, 0]'),
#  Text(0.8589743589743589, 0.6388888888888888, 'x[10] <= -0.025\ngini = 0.48\nsamples = 5\nvalue = [3, 2, 0]'),
#  Text(0.8461538461538461, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.8717948717948718, 0.5833333333333334, 'x[1] <= -1.161\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0]'),
#  Text(0.8589743589743589, 0.5277777777777778, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.8846153846153846, 0.5277777777777778, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.8846153846153846, 0.6388888888888888, 'gini = 0.0\nsamples = 6\nvalue = [6, 0, 0]'),
#  Text(0.9487179487179487, 0.75, 'x[4] <= -0.624\ngini = 0.625\nsamples = 16\nvalue = [4, 8, 4]'),
#  Text(0.9230769230769231, 0.6944444444444444, 'x[5] <= 0.768\ngini = 0.5\nsamples = 6\nvalue = [1, 1, 4]'),
#  Text(0.9102564102564102, 0.6388888888888888, 'x[2] <= 0.291\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.8974358974358975, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.9230769230769231, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9358974358974359, 0.6388888888888888, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(0.9743589743589743, 0.6944444444444444, 'x[1] <= -0.719\ngini = 0.42\nsamples = 10\nvalue = [3, 7, 0]'),
#  Text(0.9615384615384616, 0.6388888888888888, 'x[4] <= 0.188\ngini = 0.375\nsamples = 4\nvalue = [3, 1, 0]'),
#  Text(0.9487179487179487, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9743589743589743, 0.5833333333333334, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0]'),
#  Text(0.9871794871794872, 0.6388888888888888, 'gini = 0.0\nsamples = 6\nvalue = [0, 6, 0]'),
#  Text(0.9358974358974359, 0.8611111111111112, 'x[5] <= -1.14\ngini = 0.278\nsamples = 6\nvalue = [0, 5, 1]'),
#  Text(0.9230769230769231, 0.8055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.9487179487179487, 0.8055555555555556, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0]')]

# %%
clf.score(x_test,y_test)
# Out:
# 0.31666666666666665

# %%
clf.score(x_test,y_test)
# Out:
# 0.31666666666666665

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=4)
knn.fit(x_train,y_train)
# Out:
# C:\Users\vepad\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:238: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(n_neighbors=4)

# %%
knn.score(x_test,y_test)
# Out:
# 0.45

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)
model=SVC()
model.fit(x_train,y_train)
# Out:
# C:\Users\vepad\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC()

# %%
model.score(x_test,y_test)
# Out:
# 0.3

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
rf.fit(x_train,y_train)
# Out:
# C:\Users\vepad\anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier()

# %%
rf.score(x_test,y_test)
# Out:
# C:\Users\vepad\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 0.38333333333333336

# %%
x_train
# Out:
# array([[-0.70933884,  1.71133273, -0.28502063, ..., -1.02532046,
#          1.08711461, -1.20524863],
#        [ 1.38776882, -0.64573961,  1.63646674, ..., -1.02532046,
#         -0.91986621, -1.20524863],
#        [-0.42763781,  1.26938166,  1.36196855, ...,  0.97530483,
#          1.08711461,  1.18532717],
#        ...,
#        [ 0.88696699, -1.23500769, -1.21831449, ...,  0.97530483,
#          1.08711461,  1.18532717],
#        [-0.77193907, -0.20378855, -0.83401702, ...,  0.97530483,
#          1.08711461, -1.20524863],
#        [-1.46054158, -0.94037365,  0.37377504, ..., -1.02532046,
#         -0.91986621, -1.20524863]])

# %%
y_pred=rf.predict(x_test)
# Out:
# C:\Users\vepad\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# C:\Users\vepad\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.35

# %%
prd=model.predict(x_test)

# %%
prd
# Out:
# array(['Minor injury', 'Fatal crash', 'Minor injury', 'Major injury',
#        'Fatal crash', 'Major injury', 'Minor injury', 'Fatal crash',
#        'Minor injury', 'Major injury', 'Major injury', 'Fatal crash',
#        'Minor injury', 'Major injury', 'Minor injury', 'Minor injury',
#        'Minor injury', 'Minor injury', 'Fatal crash', 'Major injury',
#        'Minor injury', 'Minor injury', 'Major injury', 'Minor injury',
#        'Fatal crash', 'Major injury', 'Fatal crash', 'Fatal crash',
#        'Minor injury', 'Minor injury', 'Major injury', 'Minor injury',
#        'Major injury', 'Minor injury', 'Minor injury', 'Fatal crash',
#        'Minor injury', 'Minor injury', 'Minor injury', 'Major injury',
#        'Fatal crash', 'Fatal crash', 'Major injury', 'Fatal crash',
#        'Fatal crash', 'Fatal crash', 'Fatal crash', 'Minor injury',
#        'Major injury', 'Fatal crash', 'Fatal crash', 'Minor injury',
#        'Fatal crash', 'Fatal crash', 'Minor injury', 'Major injury',
#        'Major injury', 'Major injury', 'Major injury', 'Fatal crash'],
#       dtype=object)

# %%
y_test
# Out:
#     Crash_Severity
# 208    Fatal crash
# 188   Major injury
# 12    Minor injury
# 221    Fatal crash
# 239    Fatal crash
# 136   Major injury
# 230    Fatal crash
# 206    Fatal crash
# 52    Minor injury
# 108   Major injury
# 290    Fatal crash
# 15    Minor injury
# 184   Major injury
# 248    Fatal crash
# 22    Minor injury
# 74    Minor injury
# 270    Fatal crash
# 90    Minor injury
# 229    Fatal crash
# 164   Major injury
# 190   Major injury
# 103   Major injury
# 124   Major injury
# 129   Major injury
# 222    Fatal crash
# 116   Major injury
# 194   Major injury
# 286    Fatal crash
# 234    Fatal crash
# 295    Fatal crash
# 92    Minor injury
# 66    Minor injury
# 8     Minor injury
# 122   Major injury
# 219    Fatal crash
# 150   Major injury
# 176   Major injury
# 182   Major injury
# 299    Fatal crash
# 5     Minor injury
# 223    Fatal crash
# 89    Minor injury
# 81    Minor injury
# 34    Minor injury
# 55    Minor injury
# 139   Major injury
# 236    Fatal crash
# 64    Minor injury
# 7     Minor injury
# 45    Minor injury
# 73    Minor injury
# 213    Fatal crash
# 173   Major injury
# 106   Major injury
# 59    Minor injury
# 253    Fatal crash
# 168   Major injury
# 26    Minor injury
# 284    Fatal crash
# 153   Major injury

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,prd)
cm
# Out:
# array([[7, 5, 8],
#        [7, 6, 7],
#        [6, 6, 8]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize=(10,7))
sn.heatmap(cm,annot=True)
# Out:
# <Axes: >

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

# %%
Classifier = Sequential()

# %%
Classifier.add(Dense(units=6,kernel_initializer='he_uniform',activation='relu',input_dim=13))

# %%
Classifier.add(Dense(units=6,kernel_initializer='he_uniform',activation='relu'))

# %%
Classifier.add(Dense(units=1,kernel_initializer='glorot_uniform',activation='sigmoid'))

# %%
Classifier.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=["accuracy"])

# %%
model=Classifier.fit(x_train,y_train,validation_split=0.33,batch_size=10,epochs=30)
# Out:
# Epoch 1/30
# C:\Users\vepad\AppData\Roaming\Python\Python312\site-packages\keras\src\losses\losses.py:27: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(10, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 model=Classifier.fit(x_train,y_train,validation_split=0.33,batch_size=10,epochs=30)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# UnimplementedError: Graph execution error:
#
# Detected at node compile_loss/categorical_crossentropy/Cast defined at (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#
#   File "<frozen runpy>", line 88, in _run_code
#
#   File "C:\Users\vepad\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#
#   File "C:\Users\vepad\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#
#   File "C:\Users\vepad\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#
#   File "C:\Users\vepad\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#
#   File "C:\Users\vepad\anaconda3\Lib\asyncio\windows_events.py", line 322, in run_forever
#
#   File "C:\Users\vepad\anaconda3\Lib\asyncio\base_events.py", line 641, in run_forever
#
#   File "C:\Users\vepad\anaconda3\Lib\asyncio\base_events.py", line 1986, in _run_once
#
#   File "C:\Users\vepad\anaconda3\Lib\asyncio\events.py", line 88, in _run
#
#   File "C:\Users\vepad\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in dispatch_queue
#
#   File "C:\Users\vepad\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 523, in process_one
#
#   File "C:\Users\vepad\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 429, in dispatch_shell
#
#   File "C:\Users\vepad\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#
#   File "C:\Users\vepad\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 429, in do_execute
#
#   File "C:\Users\vepad\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#
#   File "C:\Users\vepad\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#
#   File "C:\Users\vepad\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#
#   File "C:\Users\vepad\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "C:\Users\vepad\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#
#   File "C:\Users\vepad\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#
#   File "C:\Users\vepad\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#
#   File "C:\Users\vepad\AppData\Local\Temp\ipykernel_25132\2994363114.py", line 1, in <module>
#
#   File "C:\Users\vepad\AppData\Roaming\Python\Python312\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "C:\Users\vepad\AppData\Roaming\Python\Python312\site-packages\keras\src\backend\tensorflow\trainer.py", line 320, in fit
#
#   File "C:\Users\vepad\AppData\Roaming\Python\Python312\site-packages\keras\src\backend\tensorflow\trainer.py", line 121, in one_step_on_iterator
#
#   File "C:\Users\vepad\AppData\Roaming\Python\Python312\site-packages\keras\src\backend\tensorflow\trainer.py", line 108, in one_step_on_data
#
#   File "C:\Users\vepad\AppData\Roaming\Python\Python312\site-packages\keras\src\backend\tensorflow\trainer.py", line 54, in train_step
#
#   File "C:\Users\vepad\AppData\Roaming\Python\Python312\site-packages\keras\src\trainers\trainer.py", line 359, in _compute_loss
#
#   File "C:\Users\vepad\AppData\Roaming\Python\Python312\site-packages\keras\src\trainers\trainer.py", line 327, in compute_loss
#
#   File "C:\Users\vepad\AppData\Roaming\Python\Python312\site-packages\keras\src\trainers\compile_utils.py", line 611, in __call__
#
#   File "C:\Users\vepad\AppData\Roaming\Python\Python312\site-packages\keras\src\trainers\compile_utils.py", line 652, in call
#
#   File "C:\Users\vepad\AppData\Roaming\Python\Python312\site-packages\keras\src\losses\loss.py", line 56, in __call__
#
#   File "C:\Users\vepad\AppData\Roaming\Python\Python312\site-packages\keras\src\tree\tree_api.py", line 148, in map_structure
#
#   File "C:\Users\vepad\AppData\Roaming\Python\Python312\site-packages\keras\src\tree\optree_impl.py", line 79, in map_structure
#
#   File "C:\Users\vepad\AppData\Roaming\Python\Python312\site-packages\optree\ops.py", line 747, in tree_map
#
#   File "C:\Users\vepad\AppData\Roaming\Python\Python312\site-packages\keras\src\losses\loss.py", line 57, in <lambda>
#
#   File "C:\Users\vepad\AppData\Roaming\Python\Python312\site-packages\keras\src\ops\core.py", line 822, in convert_to_tensor
#
#   File "C:\Users\vepad\AppData\Roaming\Python\Python312\site-packages\keras\src\backend\tensorflow\core.py", line 132, in convert_to_tensor
#
# Cast string to float is not supported
# 	 [[{{node compile_loss/categorical_crossentropy/Cast}}]] [Op:__inference_one_step_on_iterator_4640]

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
y_train=encoder.fit_transform(y_train)
y_train
# Out:
# array([1, 1, 2, 0, 0, 0, 0, 1, 2, 2, 1, 0, 0, 2, 1, 0, 2, 2, 1, 1, 1, 1,
#        0, 0, 0, 2, 0, 0, 0, 0, 0, 2, 0, 1, 1, 1, 1, 2, 1, 2, 0, 0, 1, 1,
#        2, 0, 0, 0, 0, 0, 1, 1, 2, 2, 0, 2, 1, 0, 1, 2, 2, 1, 2, 2, 2, 1,
#        1, 0, 1, 2, 2, 1, 2, 2, 1, 1, 0, 0, 2, 0, 2, 1, 0, 2, 1, 1, 2, 2,
#        2, 0, 0, 2, 0, 0, 0, 2, 2, 2, 0, 1, 1, 2, 2, 1, 2, 2, 2, 1, 2, 0,
#        0, 1, 0, 2, 1, 0, 1, 0, 0, 2, 1, 1, 0, 0, 1, 1, 0, 2, 0, 2, 0, 1,
#        2, 1, 1, 2, 2, 0, 2, 0, 0, 0, 2, 2, 2, 2, 0, 1, 0, 2, 0, 1, 1, 2,
#        1, 1, 0, 1, 0, 0, 1, 2, 2, 0, 2, 1, 1, 1, 0, 0, 1, 0, 2, 2, 0, 2,
#        1, 1, 2, 2, 1, 0, 2, 2, 1, 0, 1, 2, 1, 1, 2, 2, 0, 0, 2, 1, 2, 0,
#        1, 2, 1, 1, 1, 0, 0, 2, 2, 1, 1, 0, 0, 1, 0, 1, 2, 1, 0, 1, 0, 2,
#        2, 1, 0, 1, 0, 2, 1, 2, 2, 2, 0, 0, 0, 2, 1, 0, 1, 1, 2, 1],
#       dtype=int64)

# %%
model=keras.Sequential([
    keras.layers.Dense(3,input_shape=(13,),activation='sigmoid')
])
model.compile(optimizer='adam',loss="categorical_crossentropy",metrics=['accuracy'])
model.fit(x_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# C:\Users\vepad\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[130], line 5
#       1 model=keras.Sequential([
#       2     keras.layers.Dense(3,input_shape=(13,),activation='sigmoid')
#       3 ])
#       4 model.compile(optimizer='adam',loss="categorical_crossentropy",metrics=['accuracy'])
# ----> 5 model.fit(x_train,y_train,epochs=10)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\backend\tensorflow\nn.py:580, in categorical_crossentropy(target, output, from_logits, axis)
#     574     raise ValueError(
#     575         "Arguments `target` and `output` must be at least rank 1. "
#     576         "Received: "
#     577         f"target.shape={target.shape}, output.shape={output.shape}"
#     578     )
#     579 if len(target.shape) != len(output.shape):
# --> 580     raise ValueError(
#     581         "Arguments `target` and `output` must have the same rank "
#     582         "(ndim). Received: "
#     583         f"target.shape={target.shape}, output.shape={output.shape}"
#     584     )
#     585 for e1, e2 in zip(target.shape, output.shape):
#     586     if e1 is not None and e2 is not None and e1 != e2:
#
# ValueError: Arguments `target` and `output` must have the same rank (ndim). Received: target.shape=(None,), output.shape=(None, 3)
